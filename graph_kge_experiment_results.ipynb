# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

import numpy as np
import pandas as pd

# %%
#instead of 'dump.csv' specify path to csv file
mrr_results = pd.read_csv('dump.csv')

# %%
mrr_results
# Out:
#       job_id         dataset    model  reciprocal    job        job_type  \
# 0   24255754  wordcraft_data  complex           0  train          KvsAll
# 1   24255754  wordcraft_data  complex           0  train          KvsAll
# 2   24255754  wordcraft_data  complex           0  train          KvsAll
# 3   24255754  wordcraft_data  complex           0  train          KvsAll
# 4   24255754  wordcraft_data  complex           0  train          KvsAll
# 5   24255754  wordcraft_data  complex           0  train          KvsAll
# 6   24255754  wordcraft_data  complex           0  train          KvsAll
# 7   24255754  wordcraft_data  complex           0  train          KvsAll
# 8   24255754  wordcraft_data  complex           0  train          KvsAll
# 9   24255754  wordcraft_data  complex           0  train          KvsAll
# 10  24255754  wordcraft_data  complex           0  train          KvsAll
# 11  24255754  wordcraft_data  complex           0  train          KvsAll
# ...

# %%
mrr_results.plot("epoch", ["avg_loss", "metric"], subplots=True)
# Out:
# array([<AxesSubplot:xlabel='epoch'>, <AxesSubplot:xlabel='epoch'>],
#       dtype=object)
